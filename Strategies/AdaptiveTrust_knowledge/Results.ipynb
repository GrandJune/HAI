# %%
import matplotlib.pyplot as plt
import pickle
legend_properties = {'weight':'bold'}
data_folder = r"E:\data\hai-0520\Strategies_3\AdaptiveTrust_knowledge"
file = data_folder + r"\valence_across_episodes"
with open(file, 'rb') as infile:
    data = pickle.load(infile)

# Performance
x = list(range(0, 200, 10))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, data, "k-s", label="Trust")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Optimal Trust', fontweight='bold', fontsize=12)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Trust_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()
# should be start with 0.73 (organic) and 0.82 (pair)
# at the third sample, should be as close as to 1% difference

# %%
# Performance
x =  [0.25, 0.5, 0.75, 1.0]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_steps_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_steps_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Steps to Solution', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Steps_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()
print(pair_steps_across_episodes)
print(organic_steps_across_episodes)
# Out:
# [317.9338, 343.1849, 388.1598999999999, 424.6667]
# [193.10789999999997, 191.73460000000003, 187.7868, 192.55900000000003]

# %%
# Knowledge
x = [0.25, 0.5, 0.75, 1.0]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_knowledge_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_knowledge_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Knowledge Level', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Knowledge_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()
print(pair_knowledge_across_episodes)
# Out:
# [0.41235673828124997, 0.41159169921875005, 0.41042148437499987, 0.4110658203125]

# %%
# Knowledge
x = [0.25, 0.5, 0.75, 1.0]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_knowledge_quality_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_knowledge_quality_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Knowledge Level', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Knowledge_quality_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()
print(pair_knowledge_across_episodes)
# Out:
# [0.41235673828124997, 0.41159169921875005, 0.41042148437499987, 0.4110658203125]
