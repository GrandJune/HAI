# %%
import matplotlib.pyplot as plt
import pickle
legend_properties = {'weight':'bold'}
data_folder = r"E:\data\hai-0520\Accuracy"

organic_performance_file = data_folder + r"\organic_performance_across_episodes"
organic_knowledge_file = data_folder + r"\organic_knowledge_across_episodes" 
organic_steps_file = data_folder + r"\organic_steps_across_episodes"
pair_performance_file = data_folder + r"\pair_performance_across_episodes"
pair_knowledge_file = data_folder + r"\pair_knowledge_across_episodes"
pair_steps_file = data_folder + r"\pair_steps_across_episodes"

with open(organic_performance_file, 'rb') as infile:
    organic_performance_across_episodes = pickle.load(infile)
with open(organic_knowledge_file, 'rb') as infile:
    organic_knowledge_across_episodes = pickle.load(infile)
with open(organic_steps_file, 'rb') as infile:
    organic_steps_across_episodes = pickle.load(infile)
with open(pair_performance_file, 'rb') as infile:
    pair_performance_across_episodes = pickle.load(infile)
with open(pair_knowledge_file, 'rb') as infile:
    pair_knowledge_across_episodes = pickle.load(infile)
with open(pair_steps_file, 'rb') as infile:
    pair_steps_across_episodes = pickle.load(infile)

# Performance
x =  [50, 100, 150, 200, 250, 300, 350]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_performance_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_performance_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Pair_Organic_performance.png", transparent=True, dpi=300)
plt.show()
plt.clf()
print(pair_performance_across_episodes)
print(organic_performance_across_episodes)
# should be start with 0.73 (organic) and 0.82 (pair)
# at the third sample, should be as close as to 1% difference
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8cfafc72eaa6> in <module>
#      11 pair_steps_file = data_folder + r"\pair_steps_across_episodes"
#      12
# ---> 13 with open(organic_performance_file, 'rb') as infile:
#      14     organic_performance_across_episodes = pickle.load(infile)
#      15 with open(organic_knowledge_file, 'rb') as infile:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\data\\hai-0520\\Accuracy\\organic_performance_across_episodes'

# %%
# Performance
x =  [50, 100, 150, 200, 250, 300, 350]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_steps_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_steps_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Steps to Solution', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Steps_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()

# %%
# Knowledge
x = [50, 100, 150, 200, 250, 300, 350]
# x = [50, 100, 150]
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, pair_knowledge_across_episodes, "k--s", label="Pair")
plt.plot(x, organic_knowledge_across_episodes, "k-v", label="Organic")
plt.xlabel('Learning Length', fontweight='bold', fontsize=12)
plt.ylabel('Knowledge Level', fontweight='bold', fontsize=12)
# plt.xticks(x)
# ax.set_ylim(0.50, 0.95)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Knowledge_across_episodes.png", transparent=True, dpi=300)
plt.show()
plt.clf()
print(pair_knowledge_across_episodes)
# Out:
# [0.9730792480468751, 0.9899172363281252, 0.992386474609375, 0.9933602050781251, 0.9937689453124997, 0.9940231933593751, 0.994194775390625]
